# %% [markdown]
# # Equivalent circuit for the transmission line

# %% [markdown]
# Waveguide with magnetic coupling is shown in figure below.

# %% [markdown]
# |![transmission line](./static/Diagram1.png)|
# |:---:|
# |Equivalent circuit of the waveguide with magnetic coupling|

# %% [markdown]
# It may be represented as the T-circuit:

# %% [markdown]
# ![transmission line equivalent circuit](./static/Diagram2.png)

# %% [markdown]
# $$Z_1 = Z_2 = Z n^2 \tanh{\frac{L\gamma}{2}}$$

# %% [markdown]
# $$Z_3 = Z n^2\frac{1}{\sinh{L\gamma}}$$

# %% [markdown]
# To test this, we will take two structures, represented by 3-contour equivalent circuits each.
#
# When connected via waveguide, full equivalent circuit looks like so:

# %% [markdown]
# ![Two sections](./static/Diagram3.png)

# %% [markdown]
# Writing down Kirchhoff's law for the contours:

# %% [markdown]
# $$
# \begin{cases}
# \left(
#     R_1
#     +
#     R_G
#     +
#     i \omega L_1
#     +
#     \frac{1}{i \omega C_1}
#     +
#     \frac{1}{i \omega C_{coup}}
# \right)
# \dot I_1
# +
# \left(
#     i \omega M
#     -
#     \frac{1}{i \omega C_{coup}}
# \right)
# \dot I_2
# =
# U \exp{i\varphi}
# \\
# \left(
#     i \omega M
#     -
#     \frac{1}{i \omega C_{coup}}
# \right)
# \dot I_1
# +
# \left(
#     R_2
#     +
#     i \omega L_2
#     +
#     \frac{1}{i \omega C_2}
#     +
#     \frac{2}{i \omega C_{coup}}
# \right)
# \dot I_2
# +
# \left(
#     i \omega M
#     -
#     \frac{1}{i \omega C_{coup}}
# \right)
# \dot I_3
# =
# 0
# \\
# \left(
#     i \omega M
#     -
#     \frac{1}{i \omega C_{coup}}
# \right)
# \dot I_2
# +
# \left(
#     R_3
#     +
#     i \omega L_3
#     +
#     \frac{1}{i \omega C_3}
#     +
#     \frac{1}{i \omega C_{coup}}
#     +
#     Z n^2 \tanh{\frac{L\gamma}{2}}
#     +
#     Z n^2 \frac{1}{\sinh{L\gamma}}
# \right)
# \dot I_3
# +
# \left(
#     -
#     \frac{Z n^2}{\sinh{L\gamma}}\right)
# \dot I_4
# =
# 0
# \\
# \left(
#     -
#     \frac{Z n^2}{\sinh{L\gamma}}\right)
# \dot I_3
# +
# \left(
#     R_4
#     +
#     i \omega L_4
#     +
#     \frac{1}{i \omega C_4}
#     +
#     \frac{1}{i \omega C_{coup}}
#     +
#     Z n^2 \tanh{\frac{L\gamma}{2}}
#     +
#     Z n^2 \frac{1}{\sinh{L\gamma}}
# \right)
# \dot I_4
# +
# \left(
#     i \omega M
#     -
#     \frac{1}{i \omega C_{coup}}
# \right)
# \dot I_5
# =
# 0
# \\
# \left(
#     i \omega M
#     -
#     \frac{1}{i \omega C_{coup}}
# \right)
# \dot I_4
# +
# \left(
#     R_5
#     +
#     i \omega L_5
#     +
#     \frac{1}{i \omega C_5}
#     +
#     \frac{2}{i \omega C_{coup}}
# \right)
# \dot I_5
# +
# \left(
#     i \omega M
#     -
#     \frac{1}{i \omega C_{coup}}
# \right)
# \dot I_6
# =
# 0
# \\
# \left(
#     i \omega M
#     -
#     \frac{1}{i \omega C_{coup}}
# \right)
# \dot I_5
# +
# \left(
#     R_6
#     +
#     R_L
#     +
#     i \omega L_6
#     +
#     \frac{1}{i \omega C_6}
#     +
#     \frac{1}{i \omega C_{coup}}
# \right)
# \dot I_6
# =
# 0
# \end{cases}
# $$

# %% [markdown]
# After substitution of the lumped elements with distributed ones:

# %% [markdown]
# $$
# \begin{cases}
# \left(
#     1
#     -
#     \frac{f^2}{f_1^2}
#     +
#     j\frac {f}{f_1}
#     \frac{1+\chi_g}{Q_1}
# \right)
# \dot X_1
# +
# \left(
#     \frac{f^2}{f_1 f_2}
#     \frac{K_{12}^H}{2}
#     -
#     \frac{K_{12}^E}{2}
# \right)
# \dot X_2
# =
# j 4
# \sqrt{\pi\frac {f}{f_1}f P_g\frac{\chi_g}{Q_1}}	\exp (j\varphi)
# \\
# \left(
#     \frac{f^2}{f_1 f_2}
#     \frac{K_{12}^H}{2}
#     -
#     \frac{K_{12}^E}{2}
# \right)
# \dot X_1
# +
# \left(
#     1
#     -
#     \frac{f^2}{f_2^2}
#     +
#     j\frac {f}{f_2}
#     \frac{1}{Q_2}
# \right)
# \dot X_2
# +
# \left(
#     \frac{f^2}{f_2 f_3}
#     \frac{K_{23}^H}{2}
#     -
#     \frac{K_{23}^E}{2}
# \right)
# \dot X_3
# =
# 0
# \\
# \left(
#     \frac{f^2}{f_2 f_3}
#     \frac{K_{23}^H}{2}
#     -
#     \frac{K_{23}^E}{2}
# \right)
# \dot X_2
# +
# \left(
#     1
#     -
#     \frac{f^2}{f_3^2}
#     +
#     j\frac {f}{f_3 Q_3}
#     \left(1+\chi_{34}\tanh(\frac{\gamma L_W}{2})+\frac{\chi_{34}}{\sinh(\gamma L_W)}\right)
# \right)
# \dot X_3
# -
# j \frac{f}{\sinh(\gamma L_W)}
# \sqrt{\frac{\chi_{34}}{Q_3Q_4f_3f_4}}
# \dot X_4
# =
# 0
# \\
# -j \frac{f}{\sinh(\gamma L_W)}
# \sqrt{\frac{\chi_{43}}{Q_3Q_4f_3f_4}}
# \dot X_3
# +
# \left(
#     1
#     -
#     \frac{f^2}{f_4^2}
#     +
#     j\frac {f}{f_4 Q_4}
#     \left(1+\chi_{43}\tanh(\frac{\gamma L_W}{2})+\frac{\chi_{43}}{\sinh(\gamma L_W)}\right)
# \right)
# \dot X_4
# +
# \left(
#     \frac{f^2 K_{45}^H}{2f_4f_5}
#     -
#     \frac{K_{45}^E} 2
# \right)
# \dot X_5
# =
# 0
# \\
# \left(
#     \frac{f^2K_{45}^H}{2f_4f_5}
#     -
#     \frac{K_{45}^E} 2
# \right)
# \dot X_4
# +
# \left(
#     1
#     -
#     \frac{f^2}{f_5^2}
#     +
#     j\frac {f}{f_5}
#     \frac{1}{Q_5}
# \right)
# \dot X_5
# +
# \left(
#     \frac{f^2K_{56}^H}{2f_5f_6}
#     -
#     \frac{K_{56}^E} 2
# \right)
# \dot X_6
# =
# 0
# \\
# \left(
#     \frac{f^2K_{56}^H}{2f_5f_6}
#     -
#     \frac{K_{56}^E} 2
# \right)
# \dot X_5
# +
# \left(
#     1
#     -
#     \frac{f^2}{f_6^2}
#     +
#     j\frac {f}{f_6}
#     \frac{1}{Q_6}
# \right)
# \dot X_6
# =
# 0
# \end{cases}
# $$

# %% [markdown]
# This system may be represented in form:

# %% [markdown]
# $$[A][X]=[B]$$

# %% [markdown]
# We will solve it numerically.

# %% [markdown]
# ### Setup for R

# %% [markdown]
# Equations:

# %%
a11 <- "1 - f^2/data$f1^2 + 1i * f/data$f1 * (1+data$chi_g1) / data$Q1"
a12 <- "f^2 * data$Kh12 / (2*data$f1*data$f2) - data$Ke12/2"
a13 <- "0"
a14 <- "0"
a15 <- "0"
a16 <- "0"
a21 <- a12
a22 <- "1 - f^2/data$f2^2 + 1i * f/data$f2 / data$Q2"
a23 <- "f^2 * data$Kh23 / (2*data$f2*data$f3) - data$Ke23/2"
a24 <- "0"
a25 <- "0"
a26 <- "0"
a31 <- "0"
a32 <- a23
a33 <- "1 - f^2/data$f3^2 + 1i * f/data$f3 / data$Q3 *
(1 + data$chi34 * tanh((data$alpha+1i*data$beta)*data$L/2) +
data$chi34 / sinh((data$alpha+1i*data$beta)*data$L))"
a34 <- "-1i / sinh((data$alpha+1i*data$beta)*data$L) * f *
sqrt(data$chi34 / (data$Q3*data$Q4*data$f3*data$f4))"
a35 <- "0"
a36 <- "0"
a41 <- "0"
a42 <- "0"
a43 <- "-1i / sinh((data$alpha+1i*data$beta)*data$L) * f *
sqrt(data$chi43 / (data$Q3*data$Q4*data$f3*data$f4))"
a44 <- "1 - f^2/data$f4^2 + 1i * f/data$f4 / data$Q4 *
(1 + data$chi43 * tanh((data$alpha+1i*data$beta)*data$L/2) +
data$chi43 / sinh((data$alpha+1i*data$beta)*data$L))"
a45 <- "f^2 * data$Kh45 / (2*data$f4*data$f5) - data$Ke45/2"
a46 <- "0"
a51 <- "0"
a52 <- "0"
a53 <- "0"
a54 <- a45
a55 <- "1 - f^2/data$f5^2 + 1i * f/data$f5 / data$Q5"
a56 <- "f^2 * data$Kh56 / (2*data$f5*data$f6) - data$Ke56/2"
a61 <- "0"
a62 <- "0"
a63 <- "0"
a64 <- "0"
a65 <- a56
a66 <- "1 - f^2/data$f6^2 + 1i * f/data$f6 * (1+data$chi_g6) / data$Q6"

b1 <- "4i*sqrt(pi*f^2/data$f1*data$P*data$chi_g1/data$Q1)*exp(1i*data$phi)"
b2 <- "0"
b3 <- "0"
b4 <- "0"
b5 <- "0"
b6 <- "0"

# %% [markdown]
# Constants:

# %%
data = list()
data$f1      <- 2855e6
data$f2      <- 2854.15e6
data$f3      <- 2855e6
data$f4      <- 2855e6
data$f5      <- 2854.15e6
data$f6      <- 2855e6
data$Q1      <- 1.4e4
data$Q2      <- 1.4e4
data$Q3      <- 1.4e4
data$Q4      <- 1.4e4
data$Q5      <- 1.4e4
data$Q6      <- 1.4e4
data$Kh12    <- 0.000281
data$Kh23    <- 0.000281
data$Kh45    <- 0.000281
data$Kh56    <- 0.000281
data$Ke12    <- 0.003052
data$Ke23    <- 0.003052
data$Ke45    <- 0.003052
data$Ke56    <- 0.003052
data$chi_g1  <- 17.79
data$chi_g6  <- 17.79
data$L       <- 0.05
data$P       <- 1
data$alpha   <- 0
data$beta    <- 41
data$chi34   <- 17.79
data$chi43   <- 17.79
data$phi     <- 0

# %% [markdown]
# Solvers:

# %%
# Normalised amplitude solver
solveX <- function(freq, data, A, B) {
    output <- data.frame(matrix(NA, nrow = nrow(A), ncol = 0))
    for (f in freq) {
        output[as.character(f)] <- solve(apply(X = A, MARGIN = c(1,2), FUN = function(x) {eval(parse(text = x))}),
                                         apply(X = B, MARGIN = c(1), FUN = function(x) {eval(parse(text = x))}))
    }
    return(output)
}

# %% [markdown]
# Input impedance may be obtained from the equation:

# %% [markdown]
# $$
# \hat Z_{in}
# =
# \chi_g
# \left\{
#     1
#     +
#     j
#     Q_1
#     \left[
#         \frac {f}{f_1}
#         -
#         \frac{f_1}{f}
#         -
#         \left(
#             \frac{f}{f_2}
#             \frac{K_{12}^H}{2}
#             -
#             \frac{f_1}{f}
#             \frac{K_{12}^E}{2}
#         \right)
#         \frac{\dot X_2}{\dot X_1}
#      \right]
# \right\}^{-1}
# $$

# %% [markdown]
# where $\dot X_n$ are the normalized complex amplitudes in cells

# %%
z_fun <- "data$chi_g1/(1+1i*data$Q1*(f/data$f1-data$f1/f-(f*data$Kh12/(data$f2*2)-data$f1*data$Ke12/(f*2))*X2_norm))"

# Input impedance solver
solveZ <- function(X) {
    output <- list(f=NULL, z=NULL)
    freq <- as.numeric(names(X))
    X <- apply(X=X, MARGIN = c(2), FUN = function(x) {return(x/x[1])})
    for (f in freq) {
        X2_norm <- X[,as.character(f)][2]
        output$f <- append(f, output$f)
        output$z <- append(eval(parse(text = z_fun)), output$z)
    }
    return(output)
}

# %% [markdown]
# ## Comparison without transmission line

# %% [markdown]
# To test equations, lets solve the problem without transmission line.
#
# For this we will take first three equations from the system above.
# In place of the transmission line the terminating load is placed.

# %%
A <- matrix(c(a11, a21, a31,
              a12, a22, a32,
              a13, a23, a11), nrow = 3)
B <- matrix(c(b1, b2, b3), nrow = 3)

cat("A:\n")
print(A)
cat("\n\nB:\n")
print(B)
# Out:
# A:
#      [,1]
# [1,] "1 - f^2/data$f1^2 + 1i * f/data$f1 * (1+data$chi_g1) / data$Q1"
# [2,] "f^2 * data$Kh12 / (2*data$f1*data$f2) - data$Ke12/2"
# [3,] "0"
#      [,2]
# [1,] "f^2 * data$Kh12 / (2*data$f1*data$f2) - data$Ke12/2"
# [2,] "1 - f^2/data$f2^2 + 1i * f/data$f2 / data$Q2"
# [3,] "f^2 * data$Kh23 / (2*data$f2*data$f3) - data$Ke23/2"
#      [,3]
# [1,] "0"
# [2,] "f^2 * data$Kh23 / (2*data$f2*data$f3) - data$Ke23/2"
# [3,] "1 - f^2/data$f1^2 + 1i * f/data$f1 * (1+data$chi_g1) / data$Q1"
#
#
# B:
#      [,1]
# [1,] "4i*sqrt(pi*f^2/data$f1*data$P*data$chi_g1/data$Q1)*exp(1i*data$phi)"
# [2,] "0"
# [3,] "0"

# %% [markdown]
# Input impedance of such a device is shown below.

# %%
Z <- solveZ(solveX(seq(2850e6, 2860e6, length.out = 201), data, A, B))
Z_db <- 20 * log10(abs(Mod((Z$z - 1) / (Z$z + 1))))  # S11_lin = (Z-1)/(Z+1); S11_dB = 20*log10(S11_lin)
plot(x=Z$f/1e6, y=Z_db, type = 'l', ylab = "S11(dB)", xlab = "f, MHz")
grid(col='black')
# Out:
# plot without title

# %% [markdown]
# This device was simulated in FEM software.

# %% [markdown]
# |![fem model](./static/model_simple.png)|
# |:---:|
# |Model of the device in FEM software|

# %%
d <- read.csv("./static/s11_simple.txt", sep="", skip=3, col.names=c("f", "s11"))
plot(x=d$f, y=d$s11, type = 'l', ylab = "S11(dB)", xlab = "f, MHz")
grid(col=1)
# Out:
# plot without title

# %% [markdown]
# FEM solution is identical to the equivalent circuit solution.

# %% [markdown]
# ## Comparison with transmission line

# %% [markdown]
# Now we will take two devices and connect them via waveguide.

# %% [markdown]
# |![fem model](./static/model_wg.png)|
# |:---:|
# |Model two devices connected via waveguide in FEM software|

# %%
A <- matrix(c(a11, a21, a31, a41, a51, a61,
              a12, a22, a32, a42, a52, a62,
              a13, a23, a33, a43, a53, a63,
              a14, a24, a34, a44, a54, a64,
              a15, a25, a35, a45, a55, a65,
              a16, a26, a36, a46, a56, a66), nrow = 6)
B <- matrix(c(b1, b2, b3, b4, b5, b6), nrow = 6)


cat("A:\n")
print(A)
cat("\n\nB:\n")
print(B)
# Out:
# A:
#      [,1]
# [1,] "1 - f^2/data$f1^2 + 1i * f/data$f1 * (1+data$chi_g1) / data$Q1"
# [2,] "f^2 * data$Kh12 / (2*data$f1*data$f2) - data$Ke12/2"
# [3,] "0"
# [4,] "0"
# [5,] "0"
# [6,] "0"
#      [,2]
# [1,] "f^2 * data$Kh12 / (2*data$f1*data$f2) - data$Ke12/2"
# [2,] "1 - f^2/data$f2^2 + 1i * f/data$f2 / data$Q2"
# [3,] "f^2 * data$Kh23 / (2*data$f2*data$f3) - data$Ke23/2"
# [4,] "0"
# [5,] "0"
# [6,] "0"
#      [,3]
# [1,] "0"
# [2,] "f^2 * data$Kh23 / (2*data$f2*data$f3) - data$Ke23/2"
# [3,] "1 - f^2/data$f3^2 + 1i * f/data$f3 / data$Q3 *\n(1 + data$chi34 * tanh((data$alpha+1i*data$beta)*data$L/2) +\ndata$chi34 / sinh((data$alpha+1i*data$beta)*data$L))"
# [4,] "-1i / sinh((data$alpha+1i*data$beta)*data$L) * f *\nsqrt(data$chi43 / (data$Q3*data$Q4*data$f3*data$f4))"
# [5,] "0"
# [6,] "0"
#      [,4]
# [1,] "0"
# [2,] "0"
# [3,] "-1i / sinh((data$alpha+1i*data$beta)*data$L) * f *\nsqrt(data$chi34 / (data$Q3*data$Q4*data$f3*data$f4))"
# ...

# %%
dat <- seq(0.04,0.24,0.01)
data$L <- dat[1]
Z <- solveZ(solveX(seq(2850e6, 2860e6, length.out = 201), data, A, B))
Z_db <- 20 * log10(abs(Mod((Z$z - 1) / (Z$z + 1))))  # S11_lin = (Z-1)/(Z+1); S11_dB = 20*log10(S11_lin)
plot(x=Z$f/1e6, y=Z_db, type = 'l', ylab = "S11(dB)", xlab = "f, MHz", ylim = c(-60, 0))
j <- 1
for (i in dat[-1]) {
data$L <- i
j <- j+1
Z <- solveZ(solveX(seq(2850e6, 2860e6, length.out = 201), data, A, B))
Z_db <- 20 * log10(abs(Mod((Z$z - 1) / (Z$z + 1))))  # S11_lin = (Z-1)/(Z+1); S11_dB = 20*log10(S11_lin)
lines(x=Z$f/1e6, y=Z_db, type = 'l', col=j)
}
grid(col='black')
#legend("bottomright", legend=round(dat,2), lty=1, col=c(1:length(dat)))
# Out:
# plot without title

# %% [markdown]
# FEM solution:

# %%
d <- list()
for (f in dir("./static/s11_wg")) {
    d <- append(d, list(read.csv(paste0("./static/s11_wg/", f), sep="", skip=3, col.names=c("f", "s11"))))
}
# original data is in GHz so convert it to MHz
plot(x=d[[1]]$f*1000, y=d[[1]]$s11, type = 'l', ylab = "S11(dB)", xlab = "f, MHz", ylim = c(-60, 0))
d[[1]] <- NULL
j <- 2
for (i in d) {
    lines(x=i$f*1000, y=i$s11, type = 'l', col=j)
    j <- j + 1
}
grid(col=1)
# Out:
# plot without title
